# %% [markdown]
# # Pendahuluan

# %% [markdown]
# Pandemi COVID-19 telah mengubah kehidupan kita sehari-hari, mendorong banyak orang mencari hiburan melalui buku. Para startup di industri buku memanfaatkan peluang ini untuk mengembangkan aplikasi inovatif. Agar berhasil dalam bidang ini, kami akan menganalisis database untuk menginformasikan strategi penetapan harga dan pengembangan produk. Tugas kami mencakup mengidentifikasi rilis buku pasca tahun 2000, menganalisis ulasan dan penilaian pengguna, menentukan penerbit teratas, mengenali penulis terhormat, dan menilai durasi ulasan pengguna. Pendekatan berbasis data ini akan memandu kami dalam memenuhi tuntutan pembaca yang terus berubah di era COVID-19.

# %% [markdown]
# # Inisialisasi

# %%
# Impor library
import pandas as pd
from sqlalchemy import create_engine

# %%
# Menampilkan semua kolom
pd.set_option('display.max_columns', None)

pd.set_option('display.max_rows', 500)

# Lebar kolom max
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Mengakses Database

# %%
db_config = {'user': 'practicum_student',                             # nama pengguna
             'pwd': 's65BlTKV3faNIGhmvJVzOqhs',                       # kata sandi
             'host': 'rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net',
             'port': 6432,                                            # port koneksi
             'db': 'data-analyst-final-project-db'}                   # nama database

connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(db_config['user'],
                                                                     db_config['pwd'],
                                                                       db_config['host'],
                                                                       db_config['port'],
                                                                       db_config['db'])

engine = create_engine(connection_string, connect_args={'sslmode':'require'})

# %% [markdown]
# # Explore Table

# %%
query = """SELECT * FROM pg_catalog.pg_tables"""

# %%
df = pd.io.sql.read_sql(query, con = engine)

df[df['schemaname'] == 'public']
# Out:
#    schemaname           tablename         tableowner tablespace  hasindexes  \
# 66     public              author  praktikum_student       None        True
# 67     public              second  praktikum_student       None       False
# 68     public            second_b  praktikum_student       None       False
# 69     public  advertisment_costs    praktikum_admin       None        True
# 70     public             authors    praktikum_admin       None        True
# 71     public               books    praktikum_admin       None        True
# 72     public              orders    praktikum_admin       None        True
# 73     public          publishers    praktikum_admin       None        True
# 74     public             ratings    praktikum_admin       None        True
# 75     public             reviews    praktikum_admin       None        True
# 76     public              visits    praktikum_admin       None        True
#
#     hasrules  hastriggers  rowsecurity
# 66     False        False        False
# 67     False        False        False
# 68     False        False        False
# 69     False        False        False
# 70     False         True        False
# 71     False         True        False
# 72     False        False        False
# 73     False         True        False
# 74     False         True        False
# 75     False         True        False
# 76     False        False        False

# %% [markdown]
# Terdapat 11 'tablename' pada 'schemaname' public. Pada penelitian ini 'tablename' yang digunakan adalah books, authors, publishers, ratings dan reviews.

# %% [markdown]
# ## public.books

# %%
query = """
SELECT * 
FROM public.books
LIMIT 5
"""

# %%
pd.io.sql.read_sql(query, con = engine)
# Out:
#    book_id  author_id                                                  title  \
# 0        1        546                                           'Salem's Lot
# 1        2        465                     1 000 Places to See Before You Die
# 2        3        407    13 Little Blue Envelopes (Little Blue Envelope  #1)
# 3        4         82  1491: New Revelations of the Americas Before Columbus
# 4        5        125                                                   1776
#
#    num_pages publication_date  publisher_id
# 0        594       2005-11-01            93
# 1        992       2003-05-22           336
# 2        322       2010-12-21           135
# 3        541       2006-10-10           309
# 4        386       2006-07-04           268

# %% [markdown]
# **Informasi yang terdapat pada data public.books :**
# - `book_id` — ID buku
# - `author_id` — ID penulis
# - `title` — judul buku
# - `num_pages` — jumlah halaman
# - `publication_date` — tanggal penerbitan
# - `publisher_id` — ID penerbit

# %% [markdown]
# ## public.authors

# %%
query = """
SELECT * 
FROM public.authors
LIMIT 5
"""

# %%
pd.io.sql.read_sql(query, con = engine)
# Out:
#    author_id                          author
# 0          1                      A.S. Byatt
# 1          2  Aesop/Laura Harris/Laura Gibbs
# 2          3                 Agatha Christie
# 3          4                   Alan Brennert
# 4          5        Alan Moore/David   Lloyd

# %% [markdown]
# **Informasi yang terdapat pada data public.authors :**
# - `author_id` — ID penulis
# - `author` — nama penulis

# %% [markdown]
# ## public.publishers

# %%
query = """
SELECT * 
FROM public.publishers
LIMIT 5
"""

# %%
pd.io.sql.read_sql(query, con = engine)
# Out:
#    publisher_id                          publisher
# 0             1                                Ace
# 1             2                           Ace Book
# 2             3                          Ace Books
# 3             4                      Ace Hardcover
# 4             5  Addison Wesley Publishing Company

# %% [markdown]
# **Informasi yang terdapat pada data public.publishers :**
# - `publisher_id` — ID penerbit
# - `publisher` — nama penerbit

# %% [markdown]
# ## public.ratings

# %%
query = """
SELECT * 
FROM public.ratings
LIMIT 5
"""

# %%
pd.io.sql.read_sql(query, con = engine)
# Out:
#    rating_id  book_id       username  rating
# 0          1        1     ryanfranco       4
# 1          2        1  grantpatricia       2
# 2          3        1   brandtandrea       5
# 3          4        2       lorichen       3
# 4          5        2    mariokeller       2

# %% [markdown]
# **Informasi yang terdapat pada data public.publishers :**
# - `rating_id` — ID rating
# - `book_id` — ID buku
# - `username` — nama pengguna yang memberi rating buku
# - `rating` — nilai rating yang diberikan max 5

# %% [markdown]
# ## public.reviews

# %%
query = """
SELECT * 
FROM public.reviews
LIMIT 5
"""

# %%
pd.io.sql.read_sql(query, con = engine)
# Out:
#    review_id  book_id       username  \
# 0          1        1   brandtandrea
# 1          2        1     ryanfranco
# 2          3        2       lorichen
# 3          4        3  johnsonamanda
# 4          5        3    scotttamara
#
#                                                                                                                                text
# 0                                        Mention society tell send professor analysis. Over provide race technology continue these.
# 1                                                 Foot glass pretty audience hit themselves. Among admit investment argue security.
# 2  Listen treat keep worry. Miss husband tax but person sport treatment industry. Kitchen decision deep the. Social party body the.
# 3          Finally month interesting blue could nature cultural bit. Prepare beat finish grow that smile teach. Dream me play near.
# 4                  Nation purpose heavy give wait song will. List dinner another whole positive radio fast. Music staff many green.

# %% [markdown]
# **Informasi yang terdapat pada data public.reviews :**
# - `review_id` — ID ulasan
# - `book_id` — ID buku
# - `username` — nama pengguna yang mengulas buku
# - `text` — teks ulasan

# %% [markdown]
# ## Kesimpulan

# %% [markdown]
# Terdapat 5 data yang akan digunakan pada penelitian ini dari 'schemaname' public :
#
# 1. **Informasi yang terdapat pada data public.books :**
# - `book_id` — ID buku
# - `author_id` — ID penulis
# - `title` — judul buku
# - `num_pages` — jumlah halaman
# - `publication_date` — tanggal penerbitan
# - `publisher_id` — ID penerbit
#
# 2. **Informasi yang terdapat pada data public.authors :**
# - `author_id` — ID penulis
# - `author` — nama penulis
#
# 3. **Informasi yang terdapat pada data public.publishers :**
# - `publisher_id` — ID penerbit
# - `publisher` — nama penerbit
#
# 4. **Informasi yang terdapat pada data public.publishers :**
# - `rating_id` — ID rating
# - `book_id` — ID buku
# - `username` — nama pengguna yang memberi rating buku
# - `rating` — nilai rating yang diberikan max 5
#
# 5. **Informasi yang terdapat pada data public.reviews :**
# - `review_id` — ID ulasan
# - `book_id` — ID buku
# - `username` — nama pengguna yang mengulas buku
# - `text` — teks ulasan

# %% [markdown]
# # Jumlah buku yang dirilis setelah tanggal 1 Januari 2000.

# %%
query = """
SELECT COUNT(*) AS n_books
FROM public.books
WHERE publication_date > '2000-01-01'
"""

# %%
pd.io.sql.read_sql(query, con = engine)
# Out:
#    n_books
# 0      819

# %% [markdown]
# Jumlah buku yang dirilis setelah tanggal 1 Januari 2000 adalah 819.

# %% [markdown]
# # Jumlah ulasan pengguna dan rating rata-rata untuk setiap buku.

# %%
query = """
SELECT books.title,
COUNT(DISTINCT(reviews.text)) AS n_reviews,
AVG(ratings.rating) AS avg_rating
FROM public.books
JOIN public.reviews on reviews.book_id = books.book_id
JOIN public.ratings on ratings.book_id = books.book_id
GROUP BY books.title
ORDER BY n_reviews DESC
"""

# %%
pd.io.sql.read_sql(query, con = engine)
# Out:
#                                                            title  n_reviews  \
# 0                                            Memoirs of a Geisha          8
# 1                                        Twilight (Twilight  #1)          7
# 2                         The Da Vinci Code (Robert Langdon  #2)          6
# 3                                                       The Road          6
# 4    Harry Potter and the Prisoner of Azkaban (Harry Potter  #3)          6
# ..                                                           ...        ...
# 988                            Naked Empire (Sword of Truth  #8)          1
# 989                                          Moo  Baa  La La La!          1
# 990                          Merrick (The Vampire Chronicles #7)          1
# 991                                                    Babyville          1
# 992                                                   Lysistrata          1
#
#      avg_rating
# 0      4.138462
# 1      3.662500
# 2      3.830508
# 3      3.772727
# 4      4.414634
# ..          ...
# 988    3.500000
# 989    3.000000
# 990    4.000000
# 991    3.500000
# 992    4.000000
#
# [993 rows x 3 columns]

# %% [markdown]
# Terdapat 993 buku yang diulas oleh pengguna.

# %% [markdown]
# # Identifikasi penerbit yang telah menerbitkan jumlah buku terbanyak, dengan jumlah halaman lebih dari 50

# %%
query = """
SELECT publishers.publisher,
SUM(books.num_pages) AS total_pages,
COUNT(books.title) AS n_books
FROM public.publishers
JOIN public.books ON publishers.publisher_id = books.publisher_id
GROUP BY books.publisher_id,
publishers.publisher_id
HAVING SUM(books.num_pages) > 50
ORDER BY COUNT(DISTINCT(books.title)) DESC
"""

# %%
pd.io.sql.read_sql(query, con = engine)
# Out:
#                                                    publisher  total_pages  \
# 0                                              Penguin Books        15961
# 1                                                    Vintage        10895
# 2                                   Grand Central Publishing        10631
# 3                                           Penguin Classics        12247
# 4                                                     Bantam         8159
# 5                                           Ballantine Books         9495
# 6                                                    Berkley         6623
# 7                                              Berkley Books         6832
# 8                                         St. Martin's Press         4112
# 9                                              HarperCollins         4032
# 10                                                     Delta         6550
# 11                                 William Morrow Paperbacks         5120
# 12                                 Little  Brown and Company         4856
# 13                                          Harper Perennial         3989
# 14                                                 Tor Books         6933
# 15                                            Back Bay Books         4969
# 16                                                   Vertigo         2063
# 17                                                   Penguin         3569
# 18                                                    Signet         4746
# 19                                             Mariner Books         3356
# 20                                              Pocket Books         5877
# 21                                               HarperTorch         4232
# 22                                   Washington Square Press         3584
# 23                                              Anchor Books         3234
# 24                                            Modern Library         3659
# 25                                           Simon  Schuster         4151
# 26                             Random House Trade Paperbacks         4480
# 27                                                    Anchor         3322
# 28                                               Simon Pulse         3142
# 29                                   Dell Publishing Company         3576
# 30                                              Puffin Books         1200
# 31                                        Dover Publications         1067
# 32                                              Warner Books         3786
# 33                                                  Scribner         2603
# 34                                                Dial Press         2408
# 35                                              HarperTrophy         2101
# 36                          Harper Perennial Modern Classics         2092
# 37                                               Picador USA         2117
# 38                                                     Plume         3076
# 39                                            Hachette Books         1703
# 40                                              Random House         2753
# 41                                           Signet Classics         2279
# 42                                            Broadway Books         2383
# 43                          Black Dog & Leventhal Publishers         1527
# 44                                                   Spectra         3124
# 45                                                       NAL         1279
# 46                                               Square Fish         1021
# 47                                           Riverhead Books         1573
# 48                                   Oxford University Press         2394
# 49                                  HarperCollins Publishers         2228
# 50                                            William Morrow         1704
# 51                                                     Arrow         3211
# 52                                                     Corgi         1980
# 53                                     Vintage International         2003
# 54                                            Harper Voyager         2269
# 55                                                    Vision         1864
# 56                                               Atria Books         2201
# 57                                                       Ace         1932
# 58                                  Little Brown and Company         1476
# 59                                                 DC Comics          821
# 60                                             VIZ Media LLC          891
# 61                                                      Jove         2092
# 62                                           Alfred A. Knopf         1124
# 63                                             No Exit Press         1418
# 64                                               Grove Press         1089
# 65                                             Gallery Books         1083
# 66                                                 Ace Books         1546
# 67                                                   Del Rey         1545
# 68                                                 HarperOne          957
# 69                                              Bantam Books         1462
# 70                                            Gramercy Books         1292
# 71                                     Scholastic Paperbacks         1229
# 72                                                     Orbit         2600
# 73                                 Houghton Mifflin Harcourt         1190
# 74                                               Signet Book         1796
# 75                                                   Amistad          888
# 76                                            Bantam Spectra         1304
# 77                                                    Harper          980
# 78                                       Penguin Group (USA)          792
# 79                                           Delacorte Press          825
# 80                                                      Dell         2825
# 81                                         Berkley Hardcover         1056
# 82                                                Scholastic         3095
# 83                                           Scholastic Inc.         1957
# 84                                                      Avon         2011
# 85                                Dial Press Trade Paperback         2219
# 86                                          Simon & Schuster         2141
# 87                                                Avon Books         1134
# 88                                            Simon Schuster          903
# 89                                      St. Martin's Griffin         1797
# 90                                    Knopf Publishing Group          664
# 91                                                     Ember          715
# 92                                             Vintage Books          792
# 93                                        G.P. Putnam's Sons         1119
# 94                                         Warner Books (NY)         1034
# 95                                           Bantam Classics          890
# 96                                                     Orion         1504
# 97                                          Touchstone Books          443
# 98                                                    Norton          743
# 99                                          Turtleback Books          614
# 100                                          Doubleday Books          680
# 101                                  St. Martin's Paperbacks          752
# 102                                            Spectra Books         1045
# 103                                                    Speak          595
# 104                                Andrews McMeel Publishing         1664
# 105                                           Hyperion Books          836
# 106                                               Black Swan          742
# 107                                 Houghton Mifflin Company          626
# 108                                                    Crown          717
# 109                                        Vintage Books USA          928
# 110                                         Houghton Mifflin          688
# 111                                                Millenium          448
# 112                                                  Aladdin          464
# 113                     Random House Books for Young Readers          136
# 114                                Farrar  Straus and Giroux          978
# 115                                            Del Rey Books         1213
# 116                                               Debolsillo         1290
# 117                                                Daw Books          928
# 118                                    W. W. Norton  Company          665
# 119                                                   Pocket          760
# 120                                               Free Press          756
# 121                              W.W. Norton & Company (NYC)          529
# 122                                      New English Library          839
# 123                                           Crossway Books          824
# 124                                              Plume Books          610
# 125                                                  Griffin         1266
# 126                                                 Yearling          230
# 127                                   Barnes  Noble Classics          912
# 128                                        Harper Paperbacks          654
# 129                                          Harper Business          688
# 130                                        Penguin Books Ltd          760
# 131                                           Pantheon Books          346
# 132                                                 Pantheon          521
# 133                                            Thomas Nelson          499
# 134                            Knopf Books for Young Readers          320
# 135                                              Laurel Leaf          623
# 136                                                     Ecco          579
# 137                                               Kingfisher          663
# 138                                         Candlewick Press          467
# 139                             Random House: Modern Library          272
# 140                                                  Red Fox          352
# 141                                      Riverhead Hardcover          336
# 142                                                  Rizzoli          432
# 143                                                      Roc          517
# 144                                                Rupa & Co          127
# 145                                     Sarah Crichton Books          229
# 146                                         Scholastic Books          232
# 147                                         Scholastic Press          453
# 148                                                     Seal          368
# 149                                          See Sharp Press          335
# 150                                                    Seuil          344
# 151                                  Severn House Publishers          301
# 152                                          Shadow Mountain          351
# 153                                                Shambhala          273
# 154                              Simon & Schuster Paperbacks          751
# 155                             Simon & Schuster Simon Pulse          370
# 156                   Simon & Schuster; Media Tie-In edition          432
# 157                                       Simon and Schuster          403
# 158                                     Smithmark Publishers          332
# 159                                                 Starfire         2088
# 160                                                Starscape          469
# 161                                        TIme Warner Books          461
# 162                                           Tarcherperigee          320
# 163                                        The Chicken House          635
# 164                                          Thorndike Press          530
# 165                                              Titan Books          104
# 166                                  Tom Doherty Tor Fantasy         1007
# 167                                    Top Shelf Productions          592
# 168                                                      Tor          702
# 169                                              Tor Fantasy          780
# 170                                               Turtleback          283
# 171                                 Tyndale House Publishers          342
# 172                                                Vermilion           96
# 173                                          Victor Gollancz          454
# 174                                                   Viking          461
# 175                                             Viking Adult          422
# 176                                         Vintage Classics          160
# 177                                   Vintage Contemporaries          283
# 178                                            Vintage Crime          231
# 179                                                   Virago          351
# 180                                        Virago Press (UK)          441
# 181                                                  Voyager          278
# 182                                   W. W. Norton & Company          391
# 183                                    W.W. Norton & Company          320
# 184                                             Walker Books          192
# 185                                                    Warne           72
# 186                                    Warners Visions Books          640
# 187                                           Wildside Press          324
# 188        William Morrow / HarperCollins / Harper Perennial          444
# 189                              William Morrow; 1ST edition          291
# 190                                      Wordsworth Editions          339
# 191                               Workman Publishing Company          992
# 192                                               Wyatt Book          343
# 193                                    Yale University Press          179
# 194                                           Yearling Books          292
# 195                          Penguin Books /Penguin Classics          541
# 196                                                 Ace Book          335
# 197                                            Ace Hardcover          442
# 198                        Addison Wesley Publishing Company           76
# 199                                       Aladdin Paperbacks          192
# 200                                             Albin Michel          688
# 201                  Alfred A. Knopf Books for Young Readers          183
# 202                             Alfred A. Knopf Borzoi Books          357
# 203                                          Algonquin Books          335
# 204                                            Allen & Ulwin          416
# 205            Anchor Books/Knopf Doubleday Publishing Group          208
# 206                                          Applewood Books          210
# 207                                              Arrow Books          400
# 208                                          Arrow Books Ltd          144
# 209                                   Arthur A. Levine Books          128
# 210                 Arthur A. Levine Books / Scholastic Inc.          341
# 211  Atheneum Books for Young Readers: Richard Jackson Books          208
# 212                                         BALLANTINE BOOKS          290
# 213                                               Baen Books          458
# 214                                    Ballantine Books (NY)          422
# 215                                       Bantam Books  Inc.          608
# 216                              Bantam Doubleday Dell (NYC)          246
# 217                                             Bantem Press          419
# 218                                           Barnes & Noble          394
# 219                                             Beacon Press          165
# 220                                 Berkley Publishing Group          294
# 221                                    Black Dog & Leventhal          352
# 222                                      Bloomsbury Academic          488
# 223                               Bloomsbury Childrens Books          144
# 224                                 Bloomsbury Methuen Drama          336
# 225                               Cambridge University Press          289
# 226                                           Canongate U.S.          198
# 227                                             Castle Books          703
# 228                                      Children's Classics          331
# 229                                                  Citadel          288
# 230                                              City Lights           56
# 231                                          Clarkson Potter          256
# 232                                          Corgi Childrens          352
# 233                              Crown Publishing Group (NY)          463
# 234                                                      DAW         1083
# 235                        Dante University of America Press          140
# 236                                David R. Godine Publisher          138
# 237                                          Delacorte Books          384
# 238                                         Dell Laurel-Leaf          339
# 239                                         Delta Publishing          288
# 240                                                  Deodand          121
# 241                                   Devil's Due Publishing          358
# 242                                               Dial Books          364
# 243                                            Digireads.com          119
# 244                                    Disney Hyperion Books          375
# 245                                          Disney-Hyperion          452
# 246                                                Doubleday          594
# 247                                Doubleday & Company  Inc.          821
# 248                                  Dramatists Play Service          107
# 249                                                   Dutton          348
# 250                                    Ecco/Harper Perennial          312
# 251                                                      Eos          362
# 252                                       Everyman's Library          798
# 253                                             Faber  Faber          461
# 254                           Farrar  Straus and Giroux (NY)          616
# 255                                 Fourth Estate Paperbacks          653
# 256                                     Gallery / Saga Press          180
# 257                                                 Gollancz          219
# 258                                            Green Integer          188
# 259                                                HJ Kramer          240
# 260                              HMH Books for Young Readers           80
# 261                         Hackett Publishing Company  Inc.          132
# 262                             Harcourt  Inc.(Harvest Book)          232
# 263                                           Harcourt Brace          439
# 264                                            Harper Trophy          329
# 265                                  HarperCollins Perennial          927
# 266                             HarperCollins Publishers Ltd          170
# 267                             HarperCollinsChildren’sBooks           62
# 268                                  HarperCollinsPublishers          184
# 269                     HarperPerennial / Perennial Classics          288
# 270                                              HarperPrism          293
# 271                                            HarperTempest          325
# 272                           Harpercollins Children's Books           64
# 273                            Harpercollins Childrens Books          176
# 274                                                 Hartorch          265
# 275                            Harvard Business Review Press          240
# 276                                            Harvest Books          311
# 277                                          Headline Review          635
# 278                                Health Communications Inc          331
# 279                                       Henry Holt and Co.          176
# 280                                       Hodder & Stoughton          288
# 281                         Houghton Mifflin Co. (Boston/NY)          374
# 282                                     Howard Publishing Co          418
# 283                                                 Hyperion          196
# 284                                             Image Comics          304
# 285                                                   Island          535
# 286                                              Jossey-Bass          227
# 287                                               Kensington          436
# 288                                                    Knopf          433
# 289                                                      LGF          411
# 290                                     La factoría de ideas          288
# 291                                            Leisure Books          447
# 292                                Listening Library (Audio)           61
# 293                                  Little  Brown & Company          405
# 294                                                   Marvel          248
# 295                                    McGraw-Hill Education          240
# 296                                              McSweeney's          475
# 297                                  Modern Library Classics          654
# 298                                         Mysterious Press          348
# 299                                                  NAL Jam          239
# 300                                             Nelson Books          243
# 301                 New English Library (Hodder & Stoughton)          659
# 302                                   New Millennium Library          232
# 303                                        New World Library          229
# 304                                            Noonday Press          341
# 305                                                Oni Press          168
# 306                                                     Onyx          480
# 307                                            Orchard Books          401
# 308                                   Orion Publishing Group          528
# 309                                   Owl Books (Henry Holt)          240
# 310                             Oxford University Press  USA          128
# 311                                            Pan Childrens          178
# 312                                                  Pearson          128
# 313                                          Pearson Longman          353
# 314                                       Penguin (Business)          452
# 315                                    Penguin Books Limited          120
# 316                              Penguin Books Ltd. (London)          608
# 317                         Penguin Classics Deluxe Editions          180
# 318                                           Penguin Signet          592
# 319               Perennial / William Morrow / HarperCollins          256
# 320                                      Perfection Learning          232
# 321                                            Plaza y Janes          480
# 322                                            Plaza y Janés          432
# 323                    Pocket Books / Simon & Schuster  Inc.          567
# 324                                              Pocket Star          356
# 325          Prestwick House - (Literary Touchstone Classic)           75
# 326                               Princeton University Press          352
# 327                                                   Puffin          182
# 328                                                   Putnam          391
# 329                                      Random House Anchor          227
# 330                      Random House Audio Publishing Group          447
# 331                      Random House Large Print Publishing          434
# 332                                       Random House Trade          333
# 333                                     Random House Vintage          348
#
#      n_books
# 0         42
# 1         31
# 2         25
# 3         24
# 4         19
# 5         19
# 6         17
# 7         14
# 8         14
# 9         13
# 10        13
# 11        13
# 12        12
# 13        12
# 14        11
# 15        11
# 16        10
# 17        10
# 18        10
# 19        10
# 20        10
# 21        10
# 22         9
# 23         9
# 24         9
# 25         9
# 26         9
# 27         9
# 28         9
# 29         8
# 30         7
# 31         7
# 32         7
# 33         7
# 34         7
# 35         7
# 36         6
# 37         6
# 38         6
# 39         6
# 40         6
# 41         6
# 42         6
# 43         6
# 44         6
# 45         5
# 46         5
# 47         5
# 48         5
# 49         5
# 50         5
# 51         5
# 52         5
# 53         5
# 54         5
# 55         5
# 56         5
# 57         4
# 58         4
# 59         4
# 60         4
# 61         4
# 62         4
# 63         4
# 64         4
# 65         4
# 66         4
# 67         4
# 68         4
# 69         4
# 70         4
# 71         4
# 72         4
# 73         4
# 74         4
# 75         3
# 76         3
# 77         3
# 78         3
# 79         3
# 80         3
# 81         3
# 82         3
# 83         3
# 84         3
# 85         3
# 86         3
# 87         3
# 88         3
# 89         3
# 90         3
# 91         3
# 92         3
# 93         3
# 94         3
# 95         3
# 96         3
# 97         2
# 98         2
# 99         2
# 100        2
# 101        2
# 102        2
# 103        2
# 104        2
# 105        2
# 106        2
# 107        2
# 108        2
# 109        2
# 110        2
# 111        2
# 112        2
# 113        2
# 114        2
# 115        2
# 116        2
# 117        2
# 118        2
# 119        2
# 120        2
# 121        2
# 122        2
# 123        2
# 124        2
# 125        2
# 126        2
# 127        2
# 128        2
# 129        2
# 130        2
# 131        2
# 132        2
# 133        2
# 134        2
# 135        2
# 136        2
# 137        2
# 138        2
# 139        1
# 140        1
# 141        1
# 142        1
# 143        1
# 144        1
# 145        1
# 146        1
# 147        1
# 148        1
# 149        1
# 150        1
# 151        1
# 152        1
# 153        1
# 154        1
# 155        1
# 156        1
# 157        1
# 158        1
# 159        1
# 160        1
# 161        1
# 162        1
# 163        1
# 164        1
# 165        1
# 166        1
# 167        1
# 168        1
# 169        1
# 170        1
# 171        1
# 172        1
# 173        1
# 174        1
# 175        1
# 176        1
# 177        1
# 178        1
# 179        1
# 180        1
# 181        1
# 182        1
# 183        1
# 184        1
# 185        1
# 186        1
# 187        1
# 188        1
# 189        1
# 190        1
# 191        1
# 192        1
# 193        1
# 194        1
# 195        1
# 196        1
# 197        1
# 198        1
# 199        1
# 200        1
# 201        1
# 202        1
# 203        1
# 204        1
# 205        1
# 206        1
# 207        1
# 208        1
# 209        1
# 210        1
# 211        1
# 212        1
# 213        1
# 214        1
# 215        1
# 216        1
# 217        1
# 218        1
# 219        1
# 220        1
# 221        1
# 222        1
# 223        1
# 224        1
# 225        1
# 226        1
# 227        1
# 228        1
# 229        1
# 230        1
# 231        1
# 232        1
# 233        1
# 234        1
# 235        1
# 236        1
# 237        1
# 238        1
# 239        1
# 240        1
# 241        1
# 242        1
# 243        1
# 244        1
# 245        1
# 246        1
# 247        1
# 248        1
# 249        1
# 250        1
# 251        1
# 252        1
# 253        1
# 254        1
# 255        1
# 256        1
# 257        1
# 258        1
# 259        1
# 260        1
# 261        1
# 262        1
# 263        1
# 264        1
# 265        1
# 266        1
# 267        1
# 268        1
# 269        1
# 270        1
# 271        1
# 272        1
# 273        1
# 274        1
# 275        1
# 276        1
# 277        1
# 278        1
# 279        1
# 280        1
# 281        1
# 282        1
# 283        1
# 284        1
# 285        1
# 286        1
# 287        1
# 288        1
# 289        1
# 290        1
# 291        1
# 292        1
# 293        1
# 294        1
# 295        1
# 296        1
# 297        1
# 298        1
# 299        1
# 300        1
# 301        1
# 302        1
# 303        1
# 304        1
# 305        1
# 306        1
# 307        1
# 308        1
# 309        1
# 310        1
# 311        1
# 312        1
# 313        1
# 314        1
# 315        1
# 316        1
# 317        1
# 318        1
# 319        1
# 320        1
# 321        1
# 322        1
# 323        1
# 324        1
# 325        1
# 326        1
# 327        1
# 328        1
# 329        1
# 330        1
# 331        1
# 332        1
# 333        1

# %% [markdown]
# Terdapat 333 penerbit yang menerbitkan dengan total jumlah halaman lebih dari 50. Penguin Books menduduki peringkat pertama dengan jumlah buku terbanyak yang dirilis (42).

# %% [markdown]
# # Identifikasi penulis dengan rating rata-rata buku tertinggi: temukan buku dengan rating minimal 50.

# %%
query = """
SELECT authors.author,
AVG(ratings.rating) AS avg_rating,
COUNT(ratings.rating) AS n_rating
FROM public.authors
JOIN public.books ON books.author_id = authors.author_id
JOIN public.ratings ON ratings.book_id = books.book_id
GROUP BY authors.author
HAVING COUNT(ratings.rating) > 50
ORDER BY COUNT(ratings.rating) DESC
"""

# %%
pd.io.sql.read_sql(query, con = engine)
# Out:
#                                                 author  avg_rating  n_rating
# 0                           J.K. Rowling/Mary GrandPré    4.288462       312
# 1                                       J.R.R. Tolkien    4.240964       166
# 2                                      Stephenie Meyer    3.662500       160
# 3                                            Dan Brown    3.741259       143
# 4                                      Nicholas Sparks    3.882883       111
# 5                                         Stephen King    4.009434       106
# 6                                        J.D. Salinger    3.846939        98
# 7                                         Rick Riordan    4.130952        84
# 8                                         Jodi Picoult    3.881579        76
# 9              George Orwell/Boris Grabnar/Peter Škerl    3.729730        74
# 10                                      John Steinbeck    3.643836        73
# 11                                     William Golding    3.901408        71
# 12                                        John Grisham    3.971429        70
# 13  William Shakespeare/Paul Werstine/Barbara A. Mowat    3.787879        66
# 14                                          Lois Lowry    3.738462        65
# 15                                     James Patterson    3.859375        64
# 16                            Roald Dahl/Quentin Blake    4.209677        62
# 17                                     Sophie Kinsella    3.877193        57
# 18            Paulo Coelho/Alan R. Clarke/Özdemir İnce    3.789474        57
# 19                                       Arthur Golden    4.107143        56
# 20                                   Louisa May Alcott    4.203704        54
# 21                   Markus Zusak/Cao Xuân Việt Khương    4.264151        53
# 22                                     Agatha Christie    4.283019        53

# %% [markdown]
# Terdapat 22 penulis dengan jumlah rating yang diberikan pengguna diatas 50. 'J.K. Rowling/Mary GrandPré' menduduki posisi pertama dengan 312 jumlah rating yang diberikan.

# %% [markdown]
# # Jumlah rata-rata teks ulasan di antara pengguna yang memberi rating terhadap lebih dari 50 buku.

# %%
query = """
SELECT AVG(review_counts.avg_reviews) AS avg_n_reviews
FROM ( SELECT reviews.username, 
       COUNT(DISTINCT reviews.review_id) AS avg_reviews
       FROM public.reviews
       WHERE reviews.username IN (
          SELECT ratings.username
          FROM public.ratings
          GROUP BY ratings.username
          HAVING COUNT(DISTINCT ratings.book_id) > 50 )
       GROUP BY reviews.username )
    AS review_counts
"""

# %%
pd.io.sql.read_sql(query, con = engine)
# Out:
#    avg_n_reviews
# 0      24.333333

# %% [markdown]
# Rata-rata jumlah ulasan teks yang diberikan oleh pengguna yang memberikan rating kepada lebih dari 50 buku adalah 24,33 ulasan.

# %% [markdown]
# # Kesimpulan

# %% [markdown]
# Terdapat 5 data yang akan digunakan pada penelitian ini dari 'schemaname' public :
#
# 1. **Informasi yang terdapat pada data public.books :**
# - `book_id` — ID buku
# - `author_id` — ID penulis
# - `title` — judul buku
# - `num_pages` — jumlah halaman
# - `publication_date` — tanggal penerbitan
# - `publisher_id` — ID penerbit
#
# 2. **Informasi yang terdapat pada data public.authors :**
# - `author_id` — ID penulis
# - `author` — nama penulis
#
# 3. **Informasi yang terdapat pada data public.publishers :**
# - `publisher_id` — ID penerbit
# - `publisher` — nama penerbit
#
# 4. **Informasi yang terdapat pada data public.publishers :**
# - `rating_id` — ID rating
# - `book_id` — ID buku
# - `username` — nama pengguna yang memberi rating buku
# - `rating` — nilai rating yang diberikan max 5
#
# 5. **Informasi yang terdapat pada data public.reviews :**
# - `review_id` — ID ulasan
# - `book_id` — ID buku
# - `username` — nama pengguna yang mengulas buku
# - `text` — teks ulasan

# %% [markdown]
# **Hasil dari penelitian ini adalah :**
#
# 1. Jumlah buku yang dirilis setelah tanggal 1 Januari 2000 adalah 819.
#
# 2. Terdapat 993 buku yang diulas oleh pengguna.
#
# 3. Terdapat 333 penerbit yang menerbitkan buku dengan total jumlah halaman lebih dari 50. Penguin Books menduduki peringkat pertama dengan jumlah buku terbanyak yang dirilis (42).
#
# 4. Terdapat 22 penulis dengan jumlah rating yang diberikan pengguna diatas 50. 'J.K. Rowling/Mary GrandPré' menduduki posisi pertama dengan 312 jumlah rating yang diberikan.
#
# 5. Rata-rata jumlah ulasan teks yang diberikan oleh pengguna yang memberikan rating kepada lebih dari 50 buku adalah 24,33 ulasan.
